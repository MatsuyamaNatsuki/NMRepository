# %% [markdown]
# housedata()

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import (
    LinearRegression,
    Ridge,
    Lasso
)
# %matplotlib inline
import xgboost as xgb

# %%
train_ = pd.read_csv('train_house_fixed.csv')
test_ = pd.read_csv('test_house_fixed.csv')

# %%
train_
# Out:
#       Unnamed: 0  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0              0          60         65.0     8450            7            5
# 1              1          20         80.0     9600            6            8
# 2              2          60         68.0    11250            7            5
# 3              3          70         60.0     9550            7            5
# 4              4          60         84.0    14260            8            5
# ...          ...         ...          ...      ...          ...          ...
# 1455        1455          60         62.0     7917            6            5
# 1456        1456          20         85.0    13175            6            6
# 1457        1457          70         66.0     9042            7            9
# 1458        1458          20         68.0     9717            5            6
# 1459        1459          20         75.0     9937            5            6
#
# ...

# %%
test_
# Out:
#       Unnamed: 0    Id  MSSubClass  LotFrontage  LotArea  OverallQual  \
# 0              0  1461          20         80.0    11622            5
# 1              1  1462          20         81.0    14267            6
# 2              2  1463          60         74.0    13830            5
# 3              3  1464          60         78.0     9978            6
# 4              4  1465         120         43.0     5005            8
# ...          ...   ...         ...          ...      ...          ...
# 1454        1454  2915         160         21.0     1936            4
# 1455        1455  2916         160         21.0     1894            4
# 1456        1456  2917          20        160.0    20000            5
# 1457        1457  2918          85         62.0    10441            5
# 1458        1458  2919          60         74.0     9627            7
#
#       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  SaleType_NA  \
# ...

# %%
train_ = train_.drop('Unnamed: 0',axis = 1)
test_ = test_.drop('Unnamed: 0',axis = 1)

# %%
train_.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_NA  \
# 0          2003       196.0       706.0         0.0  ...            0
# 1          1976         0.0       978.0         0.0  ...            0
# 2          2002       162.0       486.0         0.0  ...            0
# 3          1970         0.0       216.0         0.0  ...            0
# 4          2000       350.0       655.0         0.0  ...            0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# ...

# %%
test_.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_NA  \
# 0       1961          1961         0.0       468.0  ...            0
# 1       1958          1958       108.0       923.0  ...            0
# 2       1997          1998         0.0       791.0  ...            0
# 3       1998          1998        20.0       602.0  ...            0
# 4       1992          1992         0.0       263.0  ...            0
#
#    SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# 0             0             0            1                      0
# ...

# %%
train_x = pd.read_csv('train_house_x_fixed.csv')
train_y = pd.read_csv('train_house_y_fixed.csv')

test_id = pd.read_csv('test_house_id_fixed.csv')
test_data = pd.read_csv('test_house_data_fixed.csv')

# %%
train_y
# Out:
#       Unnamed: 0  SalePrice
# 0              0  12.247694
# 1              1  12.109011
# 2              2  12.317167
# 3              3  11.849398
# 4              4  12.429216
# ...          ...        ...
# 1455        1455  12.072541
# 1456        1456  12.254863
# 1457        1457  12.493130
# 1458        1458  11.864462
# 1459        1459  11.901583
#
# [1460 rows x 2 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
regr_boost = GradientBoostingRegressor(n_estimators = 500,learning_rate = 0.02,max_depth =4)
X_train,X_test,y_train,y_test = train_test_split(train_x,train_y,train_size =0.3,random_state =0)

# %%
del X_train['Unnamed: 0']
X_train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 404           60          0.0    10364            6            5       1995
# 706           20          0.0   115149            7            5       1971
# 419           20         65.0     8450            5            6       1968
# 1185          50         60.0     9738            5            7       1924
# 173           20         80.0    10197            6            5       1961
# ...          ...          ...      ...          ...          ...        ...
# 763           60         82.0     9430            8            5       1999
# 835           20         60.0     9600            4            7       1950
# 1216          90         68.0     8930            6            5       1978
# 559          120          0.0     3196            7            5       2003
# 684           60         58.0    16770            7            5       1998
#
# ...

# %%
del y_train['Unnamed: 0']
y_train
# Out:
#       SalePrice
# 404   12.031719
# 706   12.618182
# 419   11.863582
# 1185  11.560763
# 173   12.001505
# ...         ...
# 763   12.727838
# 835   11.759786
# 1216  11.626254
# 559   12.363076
# 684   12.305918
#
# [438 rows x 1 columns]

# %%
regr_boost.fit(X_train,y_train)

feature_importance = regr_boost.feature_importances_*100
rel_imp = pd.Series(feature_importance,index= X_train.columns).sort_values(inplace =False)
rel_imp.T.plot(kind='barh',color='r',)
import matplotlib.pyplot as plt
plt.xlabel('Variable Importance')
plt.gca().legend_ = None
plt.show()
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_gb.py:1454: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
del train_x['Unnamed: 0']
train_x
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
del train_y['Unnamed: 0']
train_y
# Out:
#       SalePrice
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1455  12.072541
# 1456  12.254863
# 1457  12.493130
# 1458  11.864462
# 1459  11.901583
#
# [1460 rows x 1 columns]

# %% [markdown]
# 寄与度計算による変数の削減(主成分分析)

# %%
#correlation matrix
corrmat = train_.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# 変数が多すぎるので上位10個に絞り込む。

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train_[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# 'OverallQual', 'GrLivArea' and 'TotalBsmtSF' are strongly correlated with 'SalePrice'. Check!
# 'GarageCars' and 'GarageArea' are also some of the most strongly correlated variables. However, as we discussed in the last sub-point, the number of cars that fit into the garage is a consequence of the garage area. 'GarageCars' and 'GarageArea' are like twin brothers. You'll never be able to distinguish them. Therefore, we just need one of these variables in our analysis (we can keep 'GarageCars' since its correlation with 'SalePrice' is higher).
# 'TotalBsmtSF' and '1stFloor' also seem to be twin brothers. We can keep 'TotalBsmtSF' just to say that our first guess was right (re-read 'So... What can we expect?').
# 'FullBath'?? Really?
# 'TotRmsAbvGrd' and 'GrLivArea', twin brothers again. Is this dataset from Chernobyl?
# Ah... 'YearBuilt'... It seems that 'YearBuilt' is slightly correlated with 'SalePrice'. Honestly, it scares me to think about 'YearBuilt' because I start feeling that we should do a little bit of time-series analysis to get this right. I'll leave this as a homework for you.

# %% [markdown]
# 補足:15個の場合

# %%
#saleprice correlation matrix
k = 15 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train_[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# 主成分分析のその後はどうなるのか？？？

# %%
#scatterplot
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea','GarageArea','GarageCars', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'YearBuilt','BsmtQual_Ex','TotRmsAbvGrd']
sns.pairplot(train_[cols], size = 2.5)

plt.show();
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
columns_list = list(train_x.columns)

# %%
print(columns_list)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_NA', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'Street_Grvl', 'Street_Pave', 'Alley_Grvl', 'Alley_NA', 'Alley_Pave', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3', 'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS', 'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub', 'Utilities_NA', 'Utilities_NoSeWa', 'LotConfig_Corner', 'LotConfig_CulDSac', 'LotConfig_FR2', 'LotConfig_FR3', 'LotConfig_Inside', 'LandSlope_Gtl', 'LandSlope_Mod', 'LandSl
# ...

# %%
#del columns_list[0]
#print(columns_list)

# %%
top10_list = ['SalePrice', 'OverallQual', 'GrLivArea','GarageArea','GarageCars', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'YearBuilt','BsmtQual_Ex','TotRmsAbvGrd']
top10_false_list = []
for i in columns_list:
    if i in top10_list:
        pass
    else:
        top10_false_list.append(i)
print(top10_false_list)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallCond', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageYrBlt', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_NA', 'MSZoning_RH', 'MSZoning_RL', 'MSZoning_RM', 'Street_Grvl', 'Street_Pave', 'Alley_Grvl', 'Alley_NA', 'Alley_Pave', 'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3', 'LotShape_Reg', 'LandContour_Bnk', 'LandContour_HLS', 'LandContour_Low', 'LandContour_Lvl', 'Utilities_AllPub', 'Utilities_NA', 'Utilities_NoSeWa', 'LotConfig_Corner', 'LotConfig_CulDSac', 'LotConfig_FR2', 'LotConfig_FR3', 'LotConfig_Inside', 'LandSlope_Gtl', 'LandSlope_Mod', 'LandSlope_Sev', 'Neighborhood_Blmngtn', 'Neighborhood_Blueste', 'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_Clear
# ...

# %%
 train_
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
train_x.drop(top10_false_list,axis = 1)
# Out:
#       OverallQual  YearBuilt  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# 0               7       2003        856.0       856       1710         2
# 1               6       1976       1262.0      1262       1262         2
# 2               7       2001        920.0       920       1786         2
# 3               7       1915        756.0       961       1717         1
# 4               8       2000       1145.0      1145       2198         2
# ...           ...        ...          ...       ...        ...       ...
# 1455            6       1999        953.0       953       1647         2
# 1456            6       1978       1542.0      2073       2073         2
# 1457            7       1941       1152.0      1188       2340         2
# 1458            5       1950       1078.0      1078       1078         1
# 1459            5       1965       1256.0      1256       1256         1
#
#       TotRmsAbvGrd  GarageCars  GarageArea  BsmtQual_Ex
# ...

# %%
train_top10 = train_x.drop(top10_false_list,axis = 1)
#del train_top10['MSSubClass']
#del train_top10['Unnamed: 0']

# %%
train_top10_x = train_top10

# %%
#train_top10.to_csv('train_top10.csv')

# %%
train_top10_y = train_y

# %%
#del train_top10_y['Unnamed: 0']
train_top10_y
# Out:
#       SalePrice
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1455  12.072541
# 1456  12.254863
# 1457  12.493130
# 1458  11.864462
# 1459  11.901583
#
# [1460 rows x 1 columns]

# %% [markdown]
# 特徴量を10個に絞るとどうなるのか

# %%
"""
train_top10_x = train_top10.drop('SalePrice',axis = 1)
train_top10_y = train_top10['SalePrice']
"""
# Out:
# "\ntrain_top10_x = train_top10.drop('SalePrice',axis = 1)\ntrain_top10_y = train_top10['SalePrice']\n"

# %% [markdown]
# ラッソ回帰

# %%
scaler = StandardScaler()  #スケーリング
param_grid = [0.001, 0.01, 0.1, 1.0, 10.0,100.0,1000.0] #パラメータグリッド
cnt = 0
for alpha in param_grid:
    ls = Lasso(alpha=alpha) #Lasso回帰モデル
    pipeline = make_pipeline(scaler, ls) #パイプライン生成
    X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
    pipeline.fit(X_train,y_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, pipeline.predict(X_train)))
    test_rmse = np.sqrt(mean_squared_error(y_test, pipeline.predict(X_test)))
    if cnt == 0:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    elif best_score > test_rmse:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    else:
        pass
    cnt = cnt + 1
    
print('alpha : ' + str(best_param))
print('test score is : ' +str(best_score))
# Out:
# alpha : 0.01
# test score is : 0.1884054908777797

# %% [markdown]
# リッジ回帰

# %%
scaler = StandardScaler()  #スケーリング
param_grid = [0.001, 0.01, 0.1, 1.0, 10.0,100.0,1000.0] #パラメータグリッド
cnt = 0
for alpha in param_grid:
    ls = Ridge(alpha=alpha) #Ridge回帰モデル
    pipeline = make_pipeline(scaler, ls) #パイプライン生成
    X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
    pipeline.fit(X_train,y_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, pipeline.predict(X_train)))
    test_rmse = np.sqrt(mean_squared_error(y_test, pipeline.predict(X_test)))
    if cnt == 0:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    elif best_score > test_rmse:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    else:
        pass
    cnt = cnt + 1
    
print('alpha : ' + str(best_param))
print('test score is : ' +str(best_score))
# Out:
# alpha : 100.0
# test score is : 0.18985041365779415

# %%
#stop

# %% [markdown]
# 線形回帰

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
model = LinearRegression()  #線形回帰モデルの呼び出し
model.fit(X_train, y_train)  #モデルの訓練

print("1",model.coef_)  #回帰変数の表示
print("2",model.intercept_)  #回帰直線の切片
print("3",model.get_params())  #パラメータの取得

y_pred = model.predict(X_test)  #予測値の表示
print("5",model.score(X_test,y_test))  #決定係数の表示
print("MSE",mean_squared_error(y_test, y_pred))
# Out:
# 1 [[ 9.26562572e-02  2.51787100e-03  1.34253107e-04  4.80577735e-05
#    2.64596710e-04 -1.51855198e-02  7.12323950e-04  4.01511912e-02
#    1.60949166e-04  5.36158371e-02]]
# 2 [5.76483505]
# 3 {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
# 5 0.7584099896076167
# MSE 0.03732834668278327

# %% [markdown]
# 決定木

# %%
min_result = float('inf')
for i in range(1,30):
    X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
    from sklearn.tree import DecisionTreeRegressor
    regr_tree = DecisionTreeRegressor(max_depth = i)
    regr_tree.fit(X_train,y_train)
    y_pred = regr_tree.predict(X_test)
    from sklearn.metrics import mean_squared_error
    result =  mean_squared_error(y_test,y_pred)
    if result < min_result:
        min_result = result
        i_result = i
        
print("min,i",min_result,i)
# Out:
# min,i 0.04757417586750727 29

# %% [markdown]
# バギング

# %%
from sklearn.ensemble import RandomForestRegressor

X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)

all_features = X_train.shape[1]
regr_bagging = RandomForestRegressor(max_features=all_features)
regr_bagging.fit(X_train,y_train)

y_pred = regr_bagging.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 0.031643461941871724

# %% [raw]
# 特徴量の数を減らすことでリッジ回帰、ラッソ回帰でのスコアは落ちたが木構造を利用する決定木、バギングでのスコアは大きく上がっている。

# %%
from sklearn.ensemble import GradientBoostingRegressor
regr_boost = GradientBoostingRegressor(n_estimators = 500,learning_rate = 0.02,max_depth =4)
X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
regr_bagging.fit(X_train,y_train)
y_pred = regr_bagging.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.031275412541864576

# %% [markdown]
# クロスバリデーションの適用

# %% [markdown]
# クロスバリデーション(線形)

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
MSE = []

model = Pipeline([('poly', PolynomialFeatures(degree = 1)),('linear',LinearRegression())])
k_fold= KFold(n_splits=10)
test= cross_val_score(model,train_top10_x,train_top10_y,cv=k_fold,scoring='neg_mean_squared_error',n_jobs= -1)
#MSE.append(np.mean(-test))

print("MSE",np.mean(-test))
# Out:
# MSE 0.03174786560808869

# %%
"""
from sklearn.model_selection import KFold,cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
"""
"""
MSE = []
for porder in range(1, 6):
    model = Pipeline([('poly', PolynomialFeatures(degree = porder)),('linear',LinearRegression())])
    k_fold= KFold(n_splits=10)
    test= cross_val_score(model,train_top10_x,train_top10_y,cv=k_fold,scoring='neg_mean_squared_error',n_jobs= -1)
    MSE.append(np.mean(-test))
print(MSE)
print(f'mean score:{
"""

# %%
train_top10_x
# Out:
#       OverallQual  YearBuilt  TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  \
# 0               7       2003        856.0       856       1710         2
# 1               6       1976       1262.0      1262       1262         2
# 2               7       2001        920.0       920       1786         2
# 3               7       1915        756.0       961       1717         1
# 4               8       2000       1145.0      1145       2198         2
# ...           ...        ...          ...       ...        ...       ...
# 1455            6       1999        953.0       953       1647         2
# 1456            6       1978       1542.0      2073       2073         2
# 1457            7       1941       1152.0      1188       2340         2
# 1458            5       1950       1078.0      1078       1078         1
# 1459            5       1965       1256.0      1256       1256         1
#
#       TotRmsAbvGrd  GarageCars  GarageArea  BsmtQual_Ex
# ...

# %%
train_top10_y
# Out:
#       SalePrice
# 0     12.247694
# 1     12.109011
# 2     12.317167
# 3     11.849398
# 4     12.429216
# ...         ...
# 1455  12.072541
# 1456  12.254863
# 1457  12.493130
# 1458  11.864462
# 1459  11.901583
#
# [1460 rows x 1 columns]

# %% [markdown]
# ラッソ回帰-n=5のクロスバリデーション

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)

scaler = StandardScaler()
clf = LassoCV(alphas=10 ** np.arange(-6, 1, 0.1), cv=5)

scaler.fit(X_train)
clf.fit(scaler.transform(X_train), y_train)

y_pred = clf.predict(scaler.transform(X_test))
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.036457744468241085
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:1088: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# リッジ回帰-n=5のクロスバリデーション

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)

scaler = StandardScaler()
clf = RidgeCV(alphas=10 ** np.arange(-6, 1, 0.1), cv=5)

scaler.fit(X_train)
clf.fit(scaler.transform(X_train), y_train)

y_pred = clf.predict(scaler.transform(X_test))
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.037127977881561684

# %% [markdown]
# 精度が悪化した。

# %% [markdown]
# 決定木-ただしパラメータチューニングはしてある。

# %%
min_result = float('inf')
for i in range(1,30):
    X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
    from sklearn.tree import DecisionTreeRegressor
    regr_tree = DecisionTreeRegressor(max_depth = i)
    regr_tree.fit(X_train,y_train)
    y_pred = regr_tree.predict(X_test)
    from sklearn.metrics import mean_squared_error
    result =  mean_squared_error(y_test,y_pred)
    if result < min_result:
        min_result = result
        i_result = i
        
print("min,i",min_result,i)
# Out:
# min,i 0.0477734612335537 29

# %% [markdown]
# 決定木　クロスバリデーション(n=5)

# %%
min_result = float('inf')

X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
#"criterion":["gini","entropy"],を削除
diparameter={"max_depth":[i for i in range(1,30,1)],"random_state":[123],}
licv=GridSearchCV(DecisionTreeRegressor(),param_grid=diparameter,cv=5,n_jobs=5)
    

licv.fit(X_train,y_train)
y_pred = licv.predict(X_test)
from sklearn.metrics import mean_squared_error
result =  mean_squared_error(y_test,y_pred)

        
print("result",result)
# Out:
# result 0.047574175867507264

# %% [markdown]
# 決定木ではクロスバリデーションすると結果は悪化した。

# %% [markdown]
# 多重共線性を除くためにさらにパラメータを消去する。

# %%
del train_top10_x['GarageCars']
del train_top10_x['1stFlrSF']

train_top10_x
# Out:
#       OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  FullBath  TotRmsAbvGrd  \
# 0               7       2003        856.0       1710         2             8
# 1               6       1976       1262.0       1262         2             6
# 2               7       2001        920.0       1786         2             6
# 3               7       1915        756.0       1717         1             7
# 4               8       2000       1145.0       2198         2             9
# ...           ...        ...          ...        ...       ...           ...
# 1455            6       1999        953.0       1647         2             7
# 1456            6       1978       1542.0       2073         2             7
# 1457            7       1941       1152.0       2340         2             9
# 1458            5       1950       1078.0       1078         1             5
# 1459            5       1965       1256.0       1256         1             6
#
#       GarageArea  BsmtQual_Ex
# ...

# %%
scaler = StandardScaler()  #スケーリング
param_grid = [0.001, 0.01, 0.1, 1.0, 10.0,100.0,1000.0] #パラメータグリッド
cnt = 0
for alpha in param_grid:
    ls = Lasso(alpha=alpha) #Lasso回帰モデル
    pipeline = make_pipeline(scaler, ls) #パイプライン生成
    X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
    pipeline.fit(X_train,y_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, pipeline.predict(X_train)))
    test_rmse = np.sqrt(mean_squared_error(y_test, pipeline.predict(X_test)))
    if cnt == 0:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    elif best_score > test_rmse:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    else:
        pass
    cnt = cnt + 1
    
print('alpha : ' + str(best_param))
print('test score is : ' +str(best_score))
# Out:
# alpha : 0.01
# test score is : 0.19249044381308944

# %%
scaler = StandardScaler()  #スケーリング
param_grid = [0.001, 0.01, 0.1, 1.0, 10.0,100.0,1000.0] #パラメータグリッド
cnt = 0
for alpha in param_grid:
    ls = Ridge(alpha=alpha) #Ridge回帰モデル
    pipeline = make_pipeline(scaler, ls) #パイプライン生成
    X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
    pipeline.fit(X_train,y_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, pipeline.predict(X_train)))
    test_rmse = np.sqrt(mean_squared_error(y_test, pipeline.predict(X_test)))
    if cnt == 0:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    elif best_score > test_rmse:
        best_score = test_rmse
        best_estimator = pipeline
        best_param = alpha
    else:
        pass
    cnt = cnt + 1
    
print('alpha : ' + str(best_param))
print('test score is : ' +str(best_score))
# Out:
# alpha : 100.0
# test score is : 0.19321169676100414

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)
model = LinearRegression()  #線形回帰モデルの呼び出し
model.fit(X_train, y_train)  #モデルの訓練

print("1",model.coef_)  #回帰変数の表示
print("2",model.intercept_)  #回帰直線の切片
print("3",model.get_params())  #パラメータの取得

y_pred = model.predict(X_test)  #予測値の表示
print("5",model.score(X_test,y_test))  #決定係数の表示
print("MSE",mean_squared_error(y_test, y_pred))
# Out:
# 1 [[ 0.09279701  0.00258126  0.00016282  0.00027459 -0.01220367  0.00147722
#    0.00027911  0.0548471 ]]
# 2 [5.65507182]
# 3 {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}
# 5 0.7479284222583693
# MSE 0.03894786554929675

# %%
min_result = float('inf')
for i in range(1,30):
    X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
    from sklearn.tree import DecisionTreeRegressor
    regr_tree = DecisionTreeRegressor(max_depth = i)
    regr_tree.fit(X_train,y_train)
    y_pred = regr_tree.predict(X_test)
    from sklearn.metrics import mean_squared_error
    result =  mean_squared_error(y_test,y_pred)
    if result < min_result:
        min_result = result
        i_result = i
        
print("min,i",min_result,i)
# Out:
# min,i 0.0471347771418534 29

# %%
from sklearn.ensemble import RandomForestRegressor

X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)

all_features = X_train.shape[1]
regr_bagging = RandomForestRegressor(max_features=all_features)
regr_bagging.fit(X_train,y_train)

y_pred = regr_bagging.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 0.031711321156978244

# %%
from sklearn.ensemble import GradientBoostingRegressor
regr_boost = GradientBoostingRegressor(n_estimators = 500,learning_rate = 0.02,max_depth =4)
X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
regr_bagging.fit(X_train,y_train)
y_pred = regr_bagging.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.031942040514009326

# %% [markdown]
# クロスバリデーション

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)

scaler = StandardScaler()
clf = LassoCV(alphas=10 ** np.arange(-6, 1, 0.1), cv=5)

scaler.fit(X_train)
clf.fit(scaler.transform(X_train), y_train)

y_pred = clf.predict(scaler.transform(X_test))
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.03805390221724967
# /Users/matsuyamanatsuki/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:1088: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(train_top10_x, train_top10_y, test_size=0.3, random_state=0)

scaler = StandardScaler()
clf = RidgeCV(alphas=10 ** np.arange(-6, 1, 0.1), cv=5)

scaler.fit(X_train)
clf.fit(scaler.transform(X_train), y_train)

y_pred = clf.predict(scaler.transform(X_test))
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 0.038733984186403975

# %%
min_result = float('inf')

X_train,X_test,y_train,y_test = train_test_split(train_top10_x,train_top10_y,train_size =0.3,random_state =0)
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
#"criterion":["gini","entropy"],を削除
diparameter={"max_depth":[i for i in range(1,30,1)],"random_state":[123],}
licv=GridSearchCV(DecisionTreeRegressor(),param_grid=diparameter,cv=5,n_jobs=5)
    

licv.fit(X_train,y_train)
y_pred = licv.predict(X_test)
from sklearn.metrics import mean_squared_error
result =  mean_squared_error(y_test,y_pred)

        
print("result",result)
# Out:
# result 0.04713035872342285

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
MSE = []

model = Pipeline([('poly', PolynomialFeatures(degree = 1)),('linear',LinearRegression())])
k_fold= KFold(n_splits=10)
test= cross_val_score(model,train_top10_x,train_top10_y,cv=k_fold,scoring='neg_mean_squared_error',n_jobs= -1)
#MSE.append(np.mean(-test))

print("MSE",np.mean(-test))
# Out:
# MSE 0.03216522376298762
